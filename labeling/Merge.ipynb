# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## 1. Bench Press

# %%
import pandas as pd

data = pd.read_csv('benchpress/benchpress_coords.csv')

data['class'] = data['class'].str.replace('_up', '').str.replace('_down', '')

data.to_csv('benchpress/benchpress_coords_merged.csv', index=False)

# %% [markdown]
# ## 2. Squat

# %%
import pandas as pd

data = pd.read_csv('squat/squat_coords.csv')

data['class'] = data['class'].str.replace('_up', '').str.replace('_down', '')

data.to_csv('squat/squat_coords_merged.csv', index=False)

# %% [markdown]
# ## 3. Deadlift

# %%
import pandas as pd

data = pd.read_csv('deadlift/deadlift_coords.csv')

data['class'] = data['class'].str.replace('_up', '').str.replace('_down', '')

data.to_csv('deadlift/deadlift_coords_merged.csv', index=False)
